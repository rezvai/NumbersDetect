# %% [markdown]
# # 1. Подбор обучения алгоритма

# %% [markdown]
# #### Я выбрал алгоритм обучения для своей модели, обосновал почему выбрал именно его, а также подобрал параметры для оптимального применения данного алгоритма

# %% [markdown]
# # 2. Импорт данных для обчуения нейронной сети

# %% [markdown]
# #### Я подготовил датасет, он успешно импортируется, количество данных не уменьшилось, в результате импорта ошибок не возниакет

# %% [markdown]
# # 3. Обучение неронной сети

# %% [markdown]
# #### Я подготовил модель нейронной сети для поставленной задачи, она использует для обучения предоставленный набор данных, при импорте ошибок не возникает, все не используемые комментарии, а также ненужный код был удален.Код нейронной сети порыт комментариями. При обучения и использование нейронной сети ошибок не возникает. Неройнная сеть успешно обучается.

# %% [markdown]
# # 4. Разработка API

# %% [markdown]
# #### Я реализовал функцию для получения фото от пользователя, описал ее в документации, покрыл ее комметнариями и unittest-ами. Также была реализованна функция для отправки ответа в interface, которая описана в документации, покрыта комментариями и unittesta-ами. API полностью покрыто комментариями
